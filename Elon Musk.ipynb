# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\bivin\OneDrive\Desktop\Elon_musk.csv',encoding='latin1')
df
# Out:
#       Unnamed: 0                                               Text
# 0              1                             @kunalb11 Im an alien
# 1              2  @ID_AA_Carmack Ray tracing on Cyberpunk with H...
# 2              3                @joerogan @Spotify Great interview!
# 3              4                    @gtera27 Doge is underestimated
# 4              5  @teslacn Congratulations Tesla China for amazi...
# ...          ...                                                ...
# 1994        1995  @flcnhvy True, it sounds so surreal, but the n...
# 1995        1996  @PPathole Make sure to read ur terms &amp; con...
# 1996        1997                @TeslaGong @PPathole Samwise Gamgee
# 1997        1998  @PPathole Altho Dumb and Dumber is <U+0001F525...
# 1998        1999                          Progress update August 28
#
# [1999 rows x 2 columns]

# %%
df=df.drop(columns='Unnamed: 0')
df
# Out:
#                                                    Text
# 0                                @kunalb11 Im an alien
# 1     @ID_AA_Carmack Ray tracing on Cyberpunk with H...
# 2                   @joerogan @Spotify Great interview!
# 3                       @gtera27 Doge is underestimated
# 4     @teslacn Congratulations Tesla China for amazi...
# ...                                                 ...
# 1994  @flcnhvy True, it sounds so surreal, but the n...
# 1995  @PPathole Make sure to read ur terms &amp; con...
# 1996                @TeslaGong @PPathole Samwise Gamgee
# 1997  @PPathole Altho Dumb and Dumber is <U+0001F525...
# 1998                          Progress update August 28
#
# [1999 rows x 1 columns]

# %%
df.shape
# Out:
# (1999, 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    1999 non-null   object
# dtypes: object(1)
# memory usage: 15.7+ KB

# %%
df.isna().any()
# Out:
# Text    False
# dtype: bool

# %%
# converting dataframe into string
df.Text=df.Text.astype(str)

# %%
# Clean data using RegEX

# %%
import re

# %%
def cleantext(text):
    text = re.sub(r"@[A-Za-z0-9]+", "", text) # Remove Mentions
    text = re.sub(r"#", "", text) # Remove Hashtags Symbol
    text = re.sub(r"RT[\s]+", "", text) # Remove Retweets
    text = re.sub(r"https?:\/\/\S+", "", text) # Remove The Hyper Link
    text = re.sub(r"_[A-Za-z0-9]", "", text)#Removing underscores

    
    return text
df["Text"] = df["Text"].apply(cleantext)
df.head()
# Out:
#                                                 Text
# 0                                       Im an alien
# 1  Aarmack Ray tracing on Cyberpunk with HDR is n...
# 2                                   Great interview!
# 3                             Doge is underestimated
# 4   Congratulations Tesla China for amazing execu...

# %%
df.tail(10)
# Out:
#                                                    Text
# 1989                   Sorry, should hopefully be soon!
# 1990   Not actually a payout, just a vesting of stoc...
# 1991   No easy way to answer this in a tweet, but he...
# 1992                          AI symbiosis while u wait
# 1993                           Theres some of that too
# 1994   True, it sounds so surreal, but the negative ...
# 1995   Make sure to read ur terms &amp; conditions b...
# 1996                                     Samwise Gamgee
# 1997   Altho Dumb and Dumber is <U+0001F525><U+0001F...
# 1998                          Progress update August 28

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\bivin\AppData\Roaming\nltk_data...

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\bivin\anaconda3\new folder\lib\site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\bivin\anaconda3\new folder\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\bivin\anaconda3\new folder\lib\site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: pillow in c:\users\bivin\anaconda3\new folder\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bivin\anaconda3\new folder\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bivin\anaconda3\new folder\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bivin\anaconda3\new folder\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\bivin\anaconda3\new folder\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\bivin\anaconda3\new folder\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bivin\anaconda3\new folder\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\bivin\anaconda3\new folder\lib\site-packages (from matplotlib->wordcloud) (22.0)
# Requirement already satisfied: six>=1.5 in c:\users\bivin\anaconda3\new folder\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud,STOPWORDS

# %% [markdown]
# # Sentiment Values

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sentialz = SentimentIntensityAnalyzer()

# %%
sentialz.polarity_scores(df.Text.iloc[2])
# Out:
# {'neg': 0.0, 'neu': 0.185, 'pos': 0.815, 'compound': 0.6588}

# %%
def get_senti_class(review): 
    analysis = sentialz.polarity_scores(review)
    if analysis["compound"] > 0: 
        return 'positive'
    elif analysis["compound"] < 0: 
        return 'negative'
    else: 
        return 'neutral'
    
def get_senti(review):
    return pd.Series([sentialz.polarity_scores(review),get_senti_class(review)])

# %%
#Applying function to all tweets
df[["Scores", "Sentiment"]] = df.Text.apply(get_senti)
df
# Out:
#                                                    Text  \
# 0                                          Im an alien
# 1     Aarmack Ray tracing on Cyberpunk with HDR is n...
# 2                                      Great interview!
# 3                                Doge is underestimated
# 4      Congratulations Tesla China for amazing execu...
# ...                                                 ...
# 1994   True, it sounds so surreal, but the negative ...
# 1995   Make sure to read ur terms &amp; conditions b...
# 1996                                     Samwise Gamgee
# 1997   Altho Dumb and Dumber is <U+0001F525><U+0001F...
# 1998                          Progress update August 28
#
#                                                  Scores Sentiment
# 0     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
# 1     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
# 2     {'neg': 0.0, 'neu': 0.185, 'pos': 0.815, 'comp...  positive
# 3     {'neg': 0.512, 'neu': 0.488, 'pos': 0.0, 'comp...  negative
# 4     {'neg': 0.0, 'neu': 0.628, 'pos': 0.372, 'comp...  positive
# ...                                                 ...       ...
# 1994  {'neg': 0.249, 'neu': 0.561, 'pos': 0.19, 'com...  negative
# 1995  {'neg': 0.0, 'neu': 0.634, 'pos': 0.366, 'comp...  positive
# 1996  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
# 1997  {'neg': 0.592, 'neu': 0.408, 'pos': 0.0, 'comp...  negative
# 1998  {'neg': 0.0, 'neu': 0.517, 'pos': 0.483, 'comp...  positive
#
# [1999 rows x 3 columns]

# %%
comp_values = [d.get('compound') for d in df.Scores]
df.Sentiment.value_counts()
# Out:
# neutral     884
# positive    883
# negative    232
# Name: Sentiment, dtype: int64

# %%
sns.countplot(x='Sentiment',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='Sentiment', ylabel='count'>

# %%
sns.lineplot(data = comp_values, palette='rainbow')
# Out:
# <Axes: >

# %%
df.loc[df.Sentiment=='negative']
# Out:
#                                                    Text  \
# 3                                Doge is underestimated
# 6     Frodo was the underdoge,\nAll thought he would...
# 15     He definitely has issues, but the sentencing ...
# 20     Any crypto wallet that wont give you your pr...
# 21                                       Your app sucks
# ...                                                 ...
# 1965                 That is the near-term danger of AI
# 1975                   Death is the loss of information
# 1991   No easy way to answer this in a tweet, but he...
# 1994   True, it sounds so surreal, but the negative ...
# 1997   Altho Dumb and Dumber is <U+0001F525><U+0001F...
#
#                                                  Scores Sentiment
# 3     {'neg': 0.512, 'neu': 0.488, 'pos': 0.0, 'comp...  negative
# 6     {'neg': 0.226, 'neu': 0.774, 'pos': 0.0, 'comp...  negative
# 15    {'neg': 0.162, 'neu': 0.681, 'pos': 0.157, 'co...  negative
# 20    {'neg': 0.138, 'neu': 0.862, 'pos': 0.0, 'comp...  negative
# 21    {'neg': 0.556, 'neu': 0.444, 'pos': 0.0, 'comp...  negative
# ...                                                 ...       ...
# 1965  {'neg': 0.362, 'neu': 0.638, 'pos': 0.0, 'comp...  negative
# 1975  {'neg': 0.608, 'neu': 0.392, 'pos': 0.0, 'comp...  negative
# 1991  {'neg': 0.205, 'neu': 0.622, 'pos': 0.174, 'co...  negative
# 1994  {'neg': 0.249, 'neu': 0.561, 'pos': 0.19, 'com...  negative
# 1997  {'neg': 0.592, 'neu': 0.408, 'pos': 0.0, 'comp...  negative
#
# [232 rows x 3 columns]

# %%
df.loc[df.Sentiment=='positive']
# Out:
#                                                    Text  \
# 2                                      Great interview!
# 4      Congratulations Tesla China for amazing execu...
# 5                            Happy New Year of the Ox!
# 7                                    _   Haha thanks :)
# 8       Indeed! Tweets definitely do not represent r...
# ...                                                 ...
# 1988                                                Yes
# 1989                   Sorry, should hopefully be soon!
# 1990   Not actually a payout, just a vesting of stoc...
# 1995   Make sure to read ur terms &amp; conditions b...
# 1998                          Progress update August 28
#
#                                                  Scores Sentiment
# 2     {'neg': 0.0, 'neu': 0.185, 'pos': 0.815, 'comp...  positive
# 4     {'neg': 0.0, 'neu': 0.628, 'pos': 0.372, 'comp...  positive
# 5     {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'comp...  positive
# 7     {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...  positive
# 8     {'neg': 0.0, 'neu': 0.728, 'pos': 0.272, 'comp...  positive
# ...                                                 ...       ...
# 1988  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...  positive
# 1989  {'neg': 0.178, 'neu': 0.411, 'pos': 0.41, 'com...  positive
# 1990  {'neg': 0.0, 'neu': 0.925, 'pos': 0.075, 'comp...  positive
# 1995  {'neg': 0.0, 'neu': 0.634, 'pos': 0.366, 'comp...  positive
# 1998  {'neg': 0.0, 'neu': 0.517, 'pos': 0.483, 'comp...  positive
#
# [883 rows x 3 columns]

# %%
df.loc[df.Sentiment=='neutral']
# Out:
#                                                    Text  \
# 0                                          Im an alien
# 1     Aarmack Ray tracing on Cyberpunk with HDR is n...
# 10                                       Just sent some
# 12
# 13                                    Its getting real
# ...                                                 ...
# 1982                                       <U+0001F440>
# 1983    Berlin Model Y is the one to watch. That is ...
# 1992                          AI symbiosis while u wait
# 1993                           Theres some of that too
# 1996                                     Samwise Gamgee
#
#                                                  Scores Sentiment
# 0     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
# 1     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
# 10    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
# 12    {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound...   neutral
# 13    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
# ...                                                 ...       ...
# 1982  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
# 1983  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
# 1992  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
# 1993  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
# 1996  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
#
# [884 rows x 3 columns]

# %%
tweet_str = ' '.join(df['Text'].tolist())

# %%
from matplotlib.pyplot import figure
wordcloud_ip = WordCloud(
                      background_color="white", max_words=500,
               stopwords=STOPWORDS, max_font_size=200,
               random_state=42).generate(tweet_str)
figure(figsize=(2,3), dpi=300)
plt.imshow(wordcloud_ip,interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from PIL import Image
elon_mask = WordCloud(background_color='black',
                      max_words = 60, 
                    stopwords = set(STOPWORDS),
                    colormap='Purples_r',
                    
                    ).generate(tweet_str)

figure(figsize=(3,4), dpi=300)
plt.imshow(elon_mask,interpolation="bilinear")
plt.axis("off")
plt.show()
